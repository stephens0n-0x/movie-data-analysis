# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/Users/sabuhiaghayev/Desktop/movies.csv')

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability',
#        'Rotten Tomatoes %', 'Worldwide Gross', 'Year'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Film                  object
# Genre                 object
# Lead Studio           object
# Audience score %       int64
# Profitability        float64
# Rotten Tomatoes %      int64
# Worldwide Gross       object
# Year                   int64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
len(df['Film'].unique())
# Out:
# 75

# %%
movie_counts = df.groupby('Year')['Film'].count()
movie_counts
# Out:
# Year
# 2007    11
# 2008    20
# 2009    12
# 2010    20
# 2011    14
# Name: Film, dtype: int64

# %%
most_profitable = df.loc[df['Profitability'].idxmax()]
min_profitable = df.loc[df['Profitability'].idxmin()]

# %%
df["Genre"].unique()
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Romence',
#        'Comdy', 'Action', 'romance', 'comedy'], dtype=object)

# %%
df['Genre'] = df['Genre'].replace('Comdy', 'Comedy')
df['Genre'] = df['Genre'].replace('comedy', 'Comedy')
df['Genre'] = df['Genre'].replace('Romence', 'Romance')
df['Genre'] = df['Genre'].replace('romance', 'Romance')

# %%
df["Genre"].unique()
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Action'],
#       dtype=object)

# %%
comedy_df = df.loc[df['Genre'] == 'Comedy']
comedy_df
# Out:
#                                   Film   Genre            Lead Studio  \
# 1                      Youth in Revolt  Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger  Comedy            Independent
# 3                         When in Rome  Comedy                 Disney
# 4                What Happens in Vegas  Comedy                    Fox
# 9                      Valentine's Day  Comedy           Warner Bros.
# 13                      The Ugly Truth  Comedy            Independent
# 16                        The Proposal  Comedy                 Disney
# 17              The Invention of Lying  Comedy           Warner Bros.
# 18                  The Heartbreak Kid  Comedy              Paramount
# 21                    The Back-up Plan  Comedy                    CBS
# 24              She's Out of My League  Comedy              Paramount
# 25                Sex and the City Two  Comedy           Warner Bros.
# ...

# %%
sorted_df = comedy_df.sort_values('Audience score %', ascending=False)
sorted_df.head(10)[['Film', 'Year', 'Lead Studio']].to_csv("top10_comedies.csv")

# %%
df2 = pd.read_csv('top10_comedies.csv')
df2
# Out:
#    Unnamed: 0                                Film  Year   Lead Studio
# 0          54                          Knocked Up  2007     Universal
# 1          76                (500) Days of Summer  2009           Fox
# 2          27                    Sex and the City  2008  Warner Bros.
# 3          71                           Beginners  2011   Independent
# 4          69                           Enchanted  2007        Disney
# 5          44                       Marley and Me  2008           Fox
# 6          60  High School Musical 3: Senior Year  2008        Disney
# 7          46                          Mamma Mia!  2008     Universal
# 8          45                          Mamma Mia!  2008     Universal
# 9          30                            Penelope  2008        Summit

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head(50)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...

# %%
sns.countplot(x='cut', data=diamonds)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
titanic = sns.load_dataset('titanic')
titanic.head(50)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
sns.histplot(titanic['age'].dropna())
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
x = np.random.rand(5000)
y = np.random.rand(5000)
inside_circle = (x - 0.5)**2 + (y - 0.5)**2 < 0.4**2
plt.scatter(x[inside_circle], y[inside_circle], c='g', marker='x')
plt.scatter(x[~inside_circle], y[~inside_circle], c='r', marker='o')
circle = plt.Circle((0.5, 0.5), 0.4, color='k', fill=False)
plt.gca().add_artist(circle)
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.show()

# %%
x = np.random.rand(5000)
y = np.random.rand(5000) * (1 - x)
dist = np.sqrt((x - 0.7)**2 + (y - 0.3)**2)
cmap = plt.get_cmap('cool')
plt.scatter(x, y, c=dist, cmap=cmap)
plt.xlim(0, 1)
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)
